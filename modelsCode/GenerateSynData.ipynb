# %%
# %run othertrain.py

# %%
# %run cycletrain.py
# Out:
# AE(
#   (encoder): Sequential(
#     (0): Linear(in_features=49, out_features=16, bias=True)
#     (1): Sigmoid()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=16, out_features=49, bias=True)
#     (1): Sigmoid()
#   )
# )
# epoch = 9,loss = 17.379054107666015
# epoch = 19,loss = 13.517107289632161
# epoch = 29,loss = 11.336556396484376
# epoch = 39,loss = 10.037316678365071
# epoch = 49,loss = 9.270460433959961
# epoch = 59,loss = 8.808232091267904
# epoch = 69,loss = 8.521989720662434
# epoch = 79,loss = 8.352339515686035
# epoch = 89,loss = 8.260346183776855
# epoch = 99,loss = 8.208106384277343
# epoch = 109,loss = 8.17751335144043
# epoch = 119,loss = 8.15757822672526
# epoch = 129,loss = 8.145358702341715
# epoch = 139,loss = 8.133878129323323
# epoch = 149,loss = 8.12311668395996
# epoch = 159,loss = 8.1125860786438
# epoch = 169,loss = 8.102917563120524
# epoch = 179,loss = 8.095844097137451
# epoch = 189,loss = 8.088615341186523
# ...

# %%
#三列损失分别是 D0 D1 G

# %%
# %run tempcycletrain.py
